# %% [markdown]
# ## 5 number Summary And Box Plot

# %%
# Minimum, Maximum, Median, Q1, Q3, IQR

# %%
import numpy as np

# %%
lst_marks = [45,32,56,75,89,54,31,89,90,87,67,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum = np.quantile(lst_marks,[0,0.25,0.5,0.75,1.0])

minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(31.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence = Q1-1.5*(IQR)
higher_fence = Q3+1.5*(IQR)

print(lower_fence)
print(higher_fence)
# Out:
# 1.5
# 141.5

# %%
lst_marks = [45,32,56,75,89,54,31,89,90,87,67,54,45,98,99,67,74]

import seaborn as sns

sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-100,-200,45,32,56,75,89,54,31,89,90,87,67,54,45,98,99,67,74,150,170,180]

sns.boxplot(lst_marks)
# Out:
# <Axes: >
