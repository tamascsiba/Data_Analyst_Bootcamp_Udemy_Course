# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here

print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here

name = input("What's your name?")
print(name)
# Out:
# tamas

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here

number = int(input("Pick a number"))
if (number >= 1):
    print("The number is positive")
elif (number <= -1):
    print("The number is negative")
elif (number == 0):
    print("The number is zero")
# Out:
# The number is negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here

num1 = int(input("Pick a number - first"))
num2 = int(input("Pick a number - second"))
num3 = int(input("Pick a number - third"))

if ((num1 > num2) and (num1 >num3)):
    print("The first number is the greatest!")
elif ((num2 > num1) and (num2 > num3)):
    print("The second number is the greatest!")
elif ((num3 > num1) and (num3 > num2)):
    print("The third number is the greatest!")
# Out:
# The first number is the greatest!

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here

def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

num = int(input("Enter a number: "))
print(f"The factorial of {num} is {factorial(num)}")
# Out:
# The factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here

age = 25
print(age)
print(type(age))

height = 163.5
print(height)
print(type(height))

name = "Tamas"
print(name)
print(type(name))

is_True = True
print(is_True)
print(type(is_True))
# Out:
# 25
# <class 'int'>
# 163.5
# <class 'float'>
# Tamas
# <class 'str'>
# True
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here

a = 1
b = 2
c = 0

c = a
a = b
b = c

print(a)
print(b)
# Out:
# 2
# 1

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here

Celsius = int(input("Write a degree in Celsius:"))
Fahrenheit = Celsius * 1.8 + 32

print(f"{Celsius} Celsius degree is {Fahrenheit} degree in Fahrenheit")
# Out:
# 1 Celsius degree is 33.8 degree in Fahrenheit

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here

str1 = input("Write down your first name:")
str2 = input("Write down your last name:")

print(str1 + " " + str2)
# Out:
# Tamas Csiba

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here

floating_point = 12.55

if (floating_point, float):
    print(f"{floating_point} is float")
else:
    print(f"{floating_point} isn't float")
# Out:
# 12.55 is float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here

a = int(input("Pick a number"))
b = int(input("Pick another number"))

add = a+b
sub = a-b
mul = a*b
div = a/b

print(f"{a} + {b} is {add}")
print(f"{a} - {b} is {sub}")
print(f"{a} * {b} is {mul}")
print(f"{a} / {b} is {div}")
# Out:
# 5 + 4 is 9
# 5 - 4 is 1
# 5 * 4 is 20
# 5 / 4 is 1.25

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

a = int(input("Pick a number"))
b = int(input("Pick another number"))

if (a == b):
    print("The picked numbers are equal to each other")
elif{a != b}:
    print("The picked numbers aren't equal to each other")
    if(a > b):
        print(f"{a} is greater than {b}")
    elif( a < b):
        print(f"{a} is less than {b}")
# Out:
# The picked numbers aren't equal to each other
# 4 is less than 5

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

a = True
b = False

if (a and b):
    print("The AND operator is True when one of statement are equal to each other")
elif(a or b):
    print("The OR operator is True, when one of the statement is True")
print (not a)
print("The NOT operator is reverse the statement")
# Out:
# The OR operator is True, when one of the statement is True
# False
# The NOT operator is reverse the statement

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here

int1 = int(input("Pick a number"))
int1_square = pow(int1, 2)
print(f"The square of the {int1} is {int1_square}")
# Out:
# The square of the 5 is 25

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here

number = int(input("Pick a number"))

if (number % 2 == 0):
    print(f"The picked number ({number}) is even")
else:
    print(f"The picked number ({number}) is odd")
# Out:
# The picked number (15) is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

n = int(input("Enter the value of n: "))
sum = 0
if n < 0:
    print("Invalid input! Please enter a positive integer.")
else:
    for i in range(1, n + 1):
        sum = sum + i
    print("The sum of the first", n, "natural numbers is:", sum)
# Out:
# The sum of the first 10 natural numbers is: 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here

year = int(input("Enter a year: "))

# divided by 100 means century year (ending with 00)
# century year divided by 400 is leap year
if (year % 400 == 0) and (year % 100 == 0):
    print("{0} is a leap year".format(year))

# not divided by 100 means not a century year
# year divided by 4 is a leap year
elif (year % 4 ==0) and (year % 100 != 0):
    print("{0} is a leap year".format(year))

# if not divided by both 400 (century year) and 4 (not century year)
# year is not leap year
else:
    print("{0} is not a leap year".format(year))
# Out:
# 1055 is not a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

str1 = input("Write something")

str1_reversed = str1[::-1]

print(f"The {str1} reverse is {str1_reversed}")
# Out:
# The Tamas reverse is samaT

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

str1 = input("Write something")

str1_reversed = str1[::-1]

if (str1 == str1_reversed):
    print("The word is palindrome\n")
    print(f"{str1} == {str1_reversed}")
else:
    print("The word isn't palindrome\n")
    print(f"{str1} != {str1_reversed}")
# Out:
# The word isn't palindrome
#
# Tamas != samaT

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here

numbers = [34, 1, 9, 5, 22]
sorted_numbers = sorted(numbers)
print(numbers)
print(sorted_numbers)
# Out:
# [34, 1, 9, 5, 22]
# [1, 5, 9, 22, 34]
